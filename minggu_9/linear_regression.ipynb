# %% [markdown]
# # Regression

# %% [markdown]
# ## 1) IMPORT LIBRARIES AND DATASETS

# %%
# Import Pkgs
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file
advertising_df = pd.read_csv('Advertising.csv')
advertising_df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# Menghapus kolom Unnamed: 0
advertising_df = advertising_df.drop(columns=['Unnamed: 0'])

# %%
advertising_df.head(8)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2

# %%
advertising_df.tail(8)
# Out:
#         TV  Radio  Newspaper  Sales
# 192   17.2    4.1       31.6    5.9
# 193  166.8   42.0        3.6   19.6
# 194  149.7   35.6        6.0   17.3
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %% [markdown]
# ## 2) Exploratory Data Analysis (EDA) and Visualizations

# %%
# check if there are any Null values
advertising_df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# Check the dataframe info
advertising_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
# Statistical summary of the dataframe
advertising_df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
# maximum sales
max = advertising_df[advertising_df['Sales'] == advertising_df['Sales'].max()]

# %%
max
# Out:
#         TV  Radio  Newspaper  Sales
# 175  276.9   48.9       41.8   27.0

# %%
# minimum sales
min = advertising_df[advertising_df['Sales'] == advertising_df['Sales'].min()]

# %%
min
# Out:
#       TV  Radio  Newspaper  Sales
# 130  0.7   39.6        8.7    1.6

# %%
# Histogram Plotting (Data Distribution)
advertising_df.hist(bins = 30, figsize = (20,10), color = 'r')
# Out:
# array([[<Axes: title={'center': 'TV'}>,
#         <Axes: title={'center': 'Radio'}>],
#        [<Axes: title={'center': 'Newspaper'}>,
#         <Axes: title={'center': 'Sales'}>]], dtype=object)

# %%
# Plot Pairplot (Variables Relationship)
sns.pairplot(advertising_df)

# %%
# Correlation Matrix
corr_matrix = advertising_df.corr()
sns.heatmap(corr_matrix, annot = True)
plt.show()

# %%
# Regression Plot with Seaborn
sns.regplot(x='TV',y='Sales',data=advertising_df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
# Regression Plot with Seaborn
sns.regplot(x='Radio',y='Sales',data=advertising_df)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
# Regression Plot with Seaborn
sns.regplot(x='Newspaper',y='Sales',data=advertising_df)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %% [markdown]
# ## 3) TRAINING AND TESTING DATA

# %%
X = advertising_df[['TV']]
y = advertising_df[['Sales']]

# %%
X
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
y
# Out:
#      Sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
X.shape
# Out:
# (200, 1)

# %%
y.shape
# Out:
# (200, 1)

# %%
X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (200, 1)

# %%
# split the data into test and train sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=72)

# %%
X_train.shape
# Out:
# (150, 1)

# %%
X_test.shape
# Out:
# (50, 1)

# %%
print(X)
# Out:
# [[230.1]
#  [ 44.5]
#  [ 17.2]
#  [151.5]
#  [180.8]
#  [  8.7]
#  [ 57.5]
#  [120.2]
#  [  8.6]
#  [199.8]
#  [ 66.1]
#  [214.7]
#  [ 23.8]
#  [ 97.5]
#  [204.1]
#  [195.4]
#  [ 67.8]
#  [281.4]
#  [ 69.2]
#  [147.3]
#  [218.4]
#  [237.4]
#  [ 13.2]
#  [228.3]
#  [ 62.3]
#  [262.9]
#  [142.9]
#  [240.1]
#  [248.8]
#  [ 70.6]
#  [292.9]
#  [112.9]
#  [ 97.2]
#  [265.6]
#  [ 95.7]
#  [290.7]
#  [266.9]
#  [ 74.7]
#  [ 43.1]
#  [228. ]
#  [202.5]
#  [177. ]
#  [293.6]
#  [206.9]
#  [ 25.1]
#  [175.1]
#  [ 89.7]
#  [239.9]
#  [227.2]
#  [ 66.9]
#  [199.8]
#  [100.4]
#  [216.4]
#  [182.6]
#  [262.7]
#  [198.9]
#  [  7.3]
#  [136.2]
#  [210.8]
#  [210.7]
#  [ 53.5]
#  [261.3]
#  [239.3]
#  [102.7]
#  [131.1]
#  [ 69. ]
#  [ 31.5]
#  [139.3]
#  [237.4]
#  [216.8]
#  [199.1]
#  [109.8]
#  [ 26.8]
#  [129.4]
#  [213.4]
#  [ 16.9]
#  [ 27.5]
#  [120.5]
#  [  5.4]
#  [116. ]
#  [ 76.4]
#  [239.8]
#  [ 75.3]
#  [ 68.4]
#  [213.5]
#  [193.2]
#  [ 76.3]
#  [110.7]
#  [ 88.3]
#  [109.8]
# ...

# %%
# We can see that data have been shuffled by "train_test_split
X_train
# Out:
# array([[213.5],
#        [218.4],
#        [243.2],
#        [ 62.3],
#        [117.2],
#        [156.6],
#        [171.3],
#        [ 80.2],
#        [214.7],
#        [ 38.2],
#        [ 25. ],
#        [149.7],
#        [ 25.6],
#        [216.4],
#        [204.1],
#        [ 44.5],
#        [172.5],
#        [135.2],
#        [240.1],
#        [239.8],
#        [134.3],
#        [163.5],
#        [ 27.5],
#        [209.6],
#        [289.7],
#        [230.1],
#        [290.7],
#        [177. ],
#        [163.3],
#        [139.2],
#        [ 57.5],
#        [ 95.7],
#        [109.8],
#        [ 19.4],
#        [ 67.8],
#        [250.9],
#        [164.5],
#        [ 76.4],
#        [240.1],
#        [198.9],
#        [110.7],
#        [ 17.2],
#        [140.3],
#        [125.7],
#        [ 96.2],
#        [ 75.3],
#        [ 31.5],
#        [175.7],
#        [ 28.6],
#        [280.7],
#        [261.3],
#        [166.8],
#        [102.7],
#        [ 43.1],
#        [112.9],
# ...

# %% [markdown]
# ## 4) Train a Linear Regression Model

# %%
# using linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lr = LinearRegression(fit_intercept = True) # Fit intercept is the "b" parameter (y = b + mx)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Checking the accuracy
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 11.307293698654055

# %%
print('Linear Model Coefficient (m): ', lr.coef_)
print('Linear Model Coefficient (b): ', lr.intercept_)
# Out:
# Linear Model Coefficient (m):  [[0.04863619]]
# Linear Model Coefficient (b):  [7.04507119]

# %% [markdown]
# ## 5) EVALUATE TRAINED MODEL PERFORMANCE

# %%
y_pred
# Out:
# array([[15.32295005],
#        [17.10789808],
#        [ 9.77842484],
#        [20.87233888],
#        [10.37178631],
#        [16.33944634],
#        [16.46590043],
#        [11.33964642],
#        [10.29883204],
#        [19.1262998 ],
#        [17.29271559],
#        [18.14871246],
#        [20.02606925],
#        [10.71710324],
#        [17.73530488],
#        [13.82981914],
#        [20.51243111],
#        [15.65367612],
#        [10.75601218],
#        [18.13412161],
#        [ 7.68706884],
#        [ 7.86702273],
#        [17.63316889],
#        [ 7.91565892],
#        [17.86175897],
#        [ 7.30770659],
#        [10.7608758 ],
#        [ 7.24447955],
#        [ 8.26583946],
#        [18.33352997],
#        [18.59130176],
#        [19.8315245 ],
#        [ 9.94378788],
#        [10.84842094],
#        [19.82179726],
#        [15.83849363],
#        [21.29061008],
#        [19.9628422 ],
#        [ 9.13642719],
#        [17.93957686],
#        [10.41069526],
# ...

# %%
# Plotting the TRAIN DATA
plt.figure(figsize=(16,8))
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, lr.predict(X_train), color = 'red')
plt.ylabel('Sales')
plt.xlabel('TV')
plt.title('Sales vs. TV')
# Out:
# Text(0.5, 1.0, 'Sales vs. TV')

# %% [markdown]
# ## 6) Making Predictions
#  - Use the trained model to obtain the salary corresponding to eployees who have 5 years of experience

# %%
new_value = [[5.0]]
new_prediction = lr.predict(new_value)
new_prediction
# Out:
# array([[7.28825212]])

# %% [markdown]
# ## 7) Save the Model

# %%
import joblib

model_file = open("linear_regression_tv.pkl","wb")
joblib.dump(lr,model_file)
model_file.close()
